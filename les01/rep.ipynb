# %% [markdown]
# # Лабораторная работа №1
# ## Подготовка среды для анализа данных
#
# **Студент:** [Шихмагомедов Алим]
# **Группа:** [УСИС 24-4]
# **Дата выполнения:** [26.11.25]

# %% [markdown]
# ## Отчет о выполнении задания
#
# В ходе работы были выполнены следующие пункты:
#
# 1.  **Создана учетная запись в GitHub**
#     *   Аккаунт доступен по ссылке: [https://github.com/southernsails05-gif](https://github.com/southernsails05-gif)
#
# 2.  **Выполнен форк репозитория**
#     *   Форк оригинального репозитория [chebotarevsa/dap-2024](https://github.com/chebotarevsa/dap-2024) создан в личном аккаунте.
#
# 3.  **Создана учетная запись в Google Colab**
#     *   Использован аккаунт Google для входа в сервис.
#
# 4.  **Настроена интеграция Google Colab и GitHub**
#     *   Репозиторий был клонирован в среду Colab с помощью команды `!git clone`.
#     *   Настроена возможность сохранения файлов напрямую в репозиторий.
#
# 5.  **Создан данный отчет**
#     *   Отчет создан в виде блокнота Jupyter (`.ipynb`) с использованием Markdown-разметки.
#
# 6.  **Отчет сохранен в репозиторий GitHub**
#     *   Файл `rep.ipynb` сохранен в директорию `./les01` личного форка репозитория.
#
# 7.  **Создан Pull Request (PR)**
#     *   Создан PR в оригинальный репозиторий. Название соответствует формату: "1 [УСИС 24-4] [Шихмагомедов Алим]".

# %%
# Код для проверки установленных библиотек и версий
import sys
print("Версия Python:", sys.version)

# Проверка доступности основных библиотек для анализа данных
try:
    import numpy as np
    import pandas as pd
    print("NumPy version:", np.__version__)
    print("Pandas version:", pd.__version__)
    print("\nВсе основные библиотеки доступны. Среда готова к работе.")
except ImportError as e:
    print("Ошибка импорта:", e)
# Out:
# Версия Python: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# NumPy version: 2.0.2
# Pandas version: 2.2.2
#
# Все основные библиотеки доступны. Среда готова к работе.
